# %%
from bs4 import BeautifulSoup
import urllib3

# %%
from bs4 import BeautifulSoup
import urllib3
import pandas as pd
import PyPDF2 
import requests
import io
from io import BytesIO
from io import StringIO
import PyPDF2
from PyPDF2 import PdfFileReader
import re

df = pd.DataFrame([[0 for i in range(0,19)]], columns=["Year", "Range", "Amount", "Dolnośląskie", "Kujawsko-Pomorskie", "Lubelskie", "Lubuskie", "Łódzkie", "Małopolskie", "Mazowieckie", "Opolskie", "Podkarpackie", "Podlaskie", "Pomorskie", "Śląskie", "Świętokrzyskie", "Warmińsko-Mazurskie", "Wielkopolskie", "Zachodniopomorskie"])
            
for i in range(2010,2020+1):
    x = "http://wwwold.pzh.gov.pl/oldpage/epimeld/grypa/"+str(i)+"/"+str(i)+".htm"

    soup = BeautifulSoup(x, 'html.parser')

    http = urllib3.PoolManager()
    response = http.request('GET', x)
    soup = BeautifulSoup(response.data)
    for a in soup.find_all('a', href=True):
        if a['href'].startswith("G"):
            x = "http://wwwold.pzh.gov.pl/oldpage/epimeld/grypa/"+str(i)+"/"+a['href']

            r = requests.get(x)
            f = io.BytesIO(r.content)
            reader = PdfFileReader(f)
            contents = reader.getPage(0).extractText().split('\n')
            contents = (', '.join(map(str, contents)))
#             print(contents)

            try:
                start = re.search(r"POLSKA , ",contents).end()
                nr = contents[start:start+7]
                nr = nr.split(' ')
                
                start = re.search(r"Dolnoskie , ",contents).end()
                dolnoslaskie = contents[start:start+7]
                dolnoslaskie = dolnoslaskie.split(' ')
                
                start = re.search(r"Kujawsko-Pomorskie , ",contents).end()
                kujawskie = contents[start:start+7]
                kujawskie = kujawskie.split(' ')
                
                start = re.search(r"Lubelskie , ",contents).end()
                lubel = contents[start:start+7]
                lubel = lubel.split(' ')
                
                start = re.search(r" Lubuskie , ",contents).end()
                lubuskie = contents[start:start+7]
                lubuskie = lubuskie.split(' ')
                
                start = re.search(r" Łódzkie , ",contents).end()
                lodzkie = contents[start:start+7]
                lodzkie = lodzkie.split(' ')

                start = re.search(r" Małopolskie , ",contents).end()
                malo = contents[start:start+7]
                malo = malo.split(' ')

                start = re.search(r"Mazowieckie , ",contents).end()
                mazo = contents[start:start+7]
                mazo = mazo.split(' ')
                
                start = re.search(r"Opolskie , ",contents).end()
                opol = contents[start:start+7]
                opol = opol.split(' ')
            
                start = re.search(r"Podkarpackie , ",contents).end()
                podk = contents[start:start+7]
                podk = podk.split(' ')
                
                start = re.search(r"Podlaskie , ",contents).end()
                podla = contents[start:start+7]
                podla = podla.split(' ')
                
                start = re.search(r"Pomorskie , ",contents).end()
                pom = contents[start:start+7]
                pom = pom.split(' ')
                
                start = re.search(r" ie , ",contents).end()
                slaskie = contents[start:start+7]
                slaskie = slaskie.split(' ')
                
                start = re.search(r"witokrzyskie , ",contents).end()
                swieto = contents[start:start+7]
                swieto = swieto.split(' ')
                
                start = re.search(r" Warmisko-Mazurskie , ",contents).end()
                warmi = contents[start:start+7]
                warmi = warmi.split(' ')
                
                start = re.search(r" Wielkopolskie , ",contents).end()
                wielko = contents[start:start+7]
                wielko = wielko.split(' ')

                start = re.search(r"Zachodniopomorskie ",contents).end()
                zacho = contents[start:start+7]
                zacho = zacho.split(' ')

                data = i
                df_new = pd.DataFrame([[str(i), a['href'][5:8], nr[0], dolnoslaskie[0],\
                    kujawskie[0], lubel[0], lubuskie[0], lodzkie[0], malo[0], mazo[0],\
                    opol[0], podk[0], podla[0], pom[0], slaskie[0], swieto[0], warmi[0], wielko[0], zacho[0]]],\
                    columns=["Year", "Range", "Amount", "Dolnośląskie", "Kujawsko-Pomorskie", "Lubelskie", "Lubuskie", "Łódzkie", "Małopolskie", "Mazowieckie", "Opolskie", "Podkarpackie", "Podlaskie", "Pomorskie", "Śląskie", "Świętokrzyskie", "Warmińsko-Mazurskie", "Wielkopolskie", "Zachodniopomorskie"])
                df = df.append(df_new)
            except:
                pass
           

df.to_csv("2007-2020.csv", index=False)
df
# Out:
#     Year Range  Amount Dolnośląskie Kujawsko-Pomorskie Lubelskie Lubuskie  \
# 0      0     0       0            0                  0         0        0
# 0   2010   12D   23177         1702                465       292       64
# 0   2010   12C   21455         1528                443       235       46
# 0   2010   12B   23899         2222                443       293       66
# 0   2010   12A   19792         2082                598       223       85
# 0   2010   11D   20848         2230                523       277      122
# 0   2010   11C   14448         1795                514       248       29
# 0   2010   11B   18387         1213                474       172       75
# 0   2010   11A   16372         1645                477       164       86
# 0   2010   10D   18753         1892                461       207       55
# 0   2010   10C   18634         1806                489       246       83
# 0   2010   10B   19872         1917                354       222       19
# 0   2010   10A   15750          517                227       184       14
# 0   2010   09D   12631         1013                324       292       25
# 0   2010   09C   10398          909                284       231       21
# 0   2010   09B    6892          756                151       197       16
# 0   2010   09A    3604          305                 53        65        1
# 0   2010   08D    2929          259                 92        63        -
# 0   2010   08C    1806          185                 31        32        -
# 0   2010   08B    2382          280                149        52        1
# 0   2010   08A    2351          105                 46        49        -
# 0   2010   07D    2432           40                 41        29        -
# 0   2010   07C    2570          252                 47        59        -
# 0   2010   07B    3166          203                115       119        -
# 0   2010   07A    5408          402                188        70        -
# 0   2010   06D    5600          730                103        85        -
# 0   2010   06C    5534          462                243       159        3
# 0   2010   06B    6899          871                156       148        1
# 0   2010   06A    6640          599                331       106       63
# 0   2010   05D    7417          877                337       174       16
# ..   ...   ...     ...          ...                ...       ...      ...
# 0   2019   07C   31368         1536               1692      1247      226
# 0   2019   07B   36789         1780               2088       840      243
# 0   2019   07A   37794         1401               1832      1131      237
# 0   2019   06D   39564         2076               2106      1071      414
# 0   2019   06C   40785         1534               1970      1135      373
# 0   2019   06B   49088         2261               2381       906      392
# 0   2019   06A   60809         2853               3176      1655      455
# 0   2019   05D   77873         3894               4417      2135      778
# 0   2019   05C   58583         3071               2862      1864      523
# 0   2019   05B   59157         2641               3169      1597      520
# 0   2019   05A   45834         1421               1866      1401      282
# 0   2019   04D   80861         3822               4175      2686      656
# 0   2019   04C   68094         3265               2998      2098      476
# 0   2019   04B  113081         5750               5669      3520     1047
# 0   2019   04A  102173         6168               5437      3856      995
# 0   2019   03D  119224         6332               5856      4813     1309
# 0   2019   03C  133758         6964               6571      4775     1616
# 0   2019   03B  157867         9522               9543      5175     2465
# 0     4713       12723       25275     1241         2332      1922      5891
# 0     5090       16744       21493     1369         2347      2050      7310
# 0     5235       14236       19134     1258         2917      2616      7157
# 0     3765        8965       17530      824         1549      1344      4978
#
#    Śląskie Świętokrzyskie Warmińsko-Mazurskie Wielkopolskie Zachodniopomorskie
# 0        0              0                   0             0                  0
# 0     1876             73                 356          3661                442
# 0     1701             15                 267          3779                336
# 0     2058             16                 303          3979                317
# 0     1554             13                 260          2740                364
# 0     1971             17                 261          2828                282
# 0      810              6                 238          1989                296
# 0     1250             18                 226          2267                327
# 0     1368              5                 206          1986                259
# 0     1183             14                 157          2009                387
# 0     2233             13                 237          2565                251
# 0      912            125                 292          2608                289
# 0      900              3                 266          2249                275
# 0     1847              1                 193          2489                311
# 0     1203              -                 204          1699                302
# 0      941              -                 169          1052                 57
# 0      408              -                 126           522                 49
# 0      451              -                  85           441                 56
# 0      201              -                  96           336                 46
# 0      282              -                 118           297                 56
# 0      344              1                  52           314                 32
# 0      170              -                 195           270                 85
# 0      331              -                  76           312                 47
# 0      281              -                 166           431                 65
# 0      520              1                 130           562                 82
# 0      467              -                 113           728                 88
# 0      489              1                 223           583                 65
# 0      728              -                 160           786                131
# 0      333              -                 150          1075                157
# 0      316              -                 127          1003                151
# ..     ...            ...                 ...           ...                ...
# 0     2986            535                 254          4677                350
# 0     3016            581                 436          5608                387
# 0     2957            866                 517          5665                556
# 0     3535           1069                 336          5814                314
# 0     3419            703                 454          6815                734
# 0     3888            824                 342          7440               1198
# 0     5797           1486                 665          7929                850
# 0     6580           1593                 750         12991               1192
# 0     5692           1256                 467          8010                895
# 0     5363           1249                 841          8686                719
# 0     3300            776                 500          5892                591
# 0     7328           2244                1174         11502               6034
# 0     7146           1418                1186          9493               1301
# 0    11246           1664                1989         16536               1864
# 0    10640           2165                1694         14474               2702
# 0    11184           2417                2542         16093               2464
# 0    11051           3836                2878         19133               4273
# 0    12180           3806                3239         22899               4067
# 0    11674           4492                3684         24834               4529
# 0    15464           5220                4462         26099               2459
# 0    18841           6883                4709         33028               4072
# 0    27310           5736                5251         40818               4913
# 0    28971           4489                3832         28240               2859
# 0    23072           3548                3857         23645               3245
# 0    15270           3573                2759         19237               2597
# 0    11952           2269                2313         18920               2221
# 0    10544           3690                1448         15112               2005
# 0    10143           3500                2264         21882               2189
# 0     9368           2872                2171         21557               2196
# 0     7728           1423                1550         13935               2443
#
# [483 rows x 19 columns]

# %%
df = pd.read_csv("2007-2020.csv")
df = df[1:]

df["Date"] = [0 for i in range(len(df))]
Date_column = []

#Add correct type of date
for i in range(len(df)):
    m = df.Range[i+1][0:2]
    d = df.Range[i+1][2:3]
    if d == "A":
        d = "01"
    elif d == "B":
        d = "08"
    elif d == "C":
        d = "16"
    elif d == "D":
        d = "23"
    Date = str(df.Year[i+1])+m+d
    Date_column.append(Date)
df = df.drop(columns="Range")
    
df.Date = Date_column 
df.Date = pd.to_datetime(df.Date, format='%Y%m%d', errors='ignore') 
cols = df.columns.tolist()
# df=df[cols[-1:]+cols[:-1]]
df
df.to_csv('2007-2020.csv', index=False)
# Out:
# 20          45         47      331              -                   76
# 21         140        115      281              -                  166
# 22         216        188      520              1                  130
# 23         158        103      467              -                  113
# 24          85        243      489              1                  223
# 25         264        156      728              -                  160
# 26         199        331      333              -                  150
# 27         413        337      316              -                  127
# 28         432        237      364              1                  242
# 29         317        313      214              2                  123
# ..         ...        ...      ...            ...                  ...
# 451        267       1692     2986            535                  254
# 452        364       2088     3016            581                  436
# 453        368       1832     2957            866                  517
# 454        363       2106     3535           1069                  336
# 455        425       1970     3419            703                  454
# 456        434       2381     3888            824                  342
# 457        634       3176     5797           1486                  665
# 458        810       4417     6580           1593                  750
# 459        553       2862     5692           1256                  467
# 460        759       3169     5363           1249                  841
# 461        175       1866     3300            776                  500
# 462       1307       4175     7328           2244                 1174
# 463        958       2998     7146           1418                 1186
# 464       1815       5669    11246           1664                 1989
# 465       1987       5437    10640           2165                 1694
# 466       1971       5856    11184           2417                 2542
# 467       2750       6571    11051           3836                 2878
# 468       3865       9543    12180           3806                 3239
# 469       3907       9710    11674           4492                 3684
# 470       3726       8995    15464           5220                 4462
# 471       4368      12898    18841           6883                 4709
# 472       5735      15766    27310           5736                 5251
# 473       5887      11195    28971           4489                 3832
# 474       5061      11100    23072           3548                 3857
# 475       3823       6558    15270           3573                 2759
# 476       4410       7260    11952           2269                 2313
# 477       1922       5891    10544           3690                 1448
# 478       2050       7310    10143           3500                 2264
# 479       2616       7157     9368           2872                 2171
# 480       1344       4978     7728           1423                 1550
#
#      Wielkopolskie  Zachodniopomorskie
# 0             3779                 336
# 1             3979                 317
# 2             2740                 364
# 3             2828                 282
# 4             1989                 296
# 5             2267                 327
# 6             1986                 259
# 7             2009                 387
# 8             2565                 251
# 9             2608                 289
# 10            2249                 275
# 11            2489                 311
# 12            1699                 302
# 13            1052                  57
# 14             522                  49
# 15             441                  56
# 16             336                  46
# 17             297                  56
# 18             314                  32
# 19             270                  85
# 20             312                  47
# 21             431                  65
# 22             562                  82
# 23             728                  88
# 24             583                  65
# 25             786                 131
# 26            1075                 157
# 27            1003                 151
# 28             876                 183
# 29             874                 220
# ..             ...                 ...
# 451           4677                 350
# 452           5608                 387
# 453           5665                 556
# 454           5814                 314
# 455           6815                 734
# 456           7440                1198
# 457           7929                 850
# 458          12991                1192
# 459           8010                 895
# 460           8686                 719
# 461           5892                 591
# 462          11502                6034
# 463           9493                1301
# 464          16536                1864
# 465          14474                2702
# 466          16093                2464
# 467          19133                4273
# 468          22899                4067
# 469          24834                4529
# 470          26099                2459
# 471          33028                4072
# 472          40818                4913
# 473          28240                2859
# 474          23645                3245
# 475          19237                2597
# 476          18920                2221
# 477          15112                2005
# 478          21882                2189
# 479          21557                2196
# 480          13935                2443
#
# [481 rows x 19 columns]

# %%
df_meld = pd.read_csv("2007-2020.csv")
df_meld.head()
# Out:
#          Date  Year  Amount  Dolnośląskie  Kujawsko-Pomorskie  Lubelskie  \
# 0  2010-12-16  2010   21455          1528                 443        235
# 1  2010-12-08  2010   23899          2222                 443        293
# 2  2010-12-01  2010   19792          2082                 598        223
# 3  2010-11-23  2010   20848          2230                 523        277
# 4  2010-11-16  2010   14448          1795                 514        248
#
#   Lubuskie  Łódzkie  Małopolskie  Mazowieckie  Opolskie Podkarpackie  \
# 0       46     1121         2806         5171       904         1245
# 1       66     1859         3258         5463       581         1063
# 2       85      702         1056         6850       727          969
# 3      122     1213         1439         5862       864         1104
# 4       29     1055          791         4043       266          919
#
#    Podlaskie  Pomorskie  Śląskie Świętokrzyskie  Warmińsko-Mazurskie  \
# 0        747        443     1701             15                  267
# 1        655        443     2058             16                  303
# 2        660        598     1554             13                  260
# 3        798        523     1971             17                  261
# 4        627        514      810              6                  238
#
#    Wielkopolskie  Zachodniopomorskie
# 0           3779                 336
# 1           3979                 317
# 2           2740                 364
# 3           2828                 282
# 4           1989                 296

# %%
df_new = pd.DataFrame([[0 for i in range(0,3)]], columns=["Date", "Place", "Ill"])

for i in range(3,19): #for each voideship
    for j in range(df_meld.shape[0]): #for each date
        Date = df_meld.Date[j]
        Place = df_meld.columns[i]
        Ill = df_meld.iloc[j:j+1,i:i+1].values[0][0]
        df_new2 = pd.DataFrame([[Date, Place, Ill]],  columns=["Date", "Place", "Ill"])
        df_new = pd.concat([df_new, df_new2])

df_new = df_new[1:]
df_new.to_csv("2007-2020.csv", index=False)

# %%
df_meld = pd.read_csv("2007-2020.csv")
df_meld.head()
# Out:
#          Date         Place   Ill
# 0  2010-12-16  Dolnośląskie  1528
# 1  2010-12-08  Dolnośląskie  2222
# 2  2010-12-01  Dolnośląskie  2082
# 3  2010-11-23  Dolnośląskie  2230
# 4  2010-11-16  Dolnośląskie  1795

# %%
df_k = pd.read_csv("Klimat_d_t.csv", header=0)
df_k['Date'] = df_k['Rok'].astype(str).str.cat(df_k['Miesiąc'].astype(str),sep="-").astype(str).str.cat(df_k['Dzień'].astype(str),sep="-")
cols = df_k.columns.tolist()
cols = cols[-1:] + cols[:-1]
df_k = df_k[cols]
df_k['Nazwa stacji'] = df_k['Nazwa stacji'].str.lower()
df_k = df_k[df_k.Date > '2010-01-01']

# %%
df = pd.DataFrame([[0 for i in range(0,19)]], columns=["Year", "Range", "Amount", "Dolnośląskie", "Kujawsko-Pomorski", "Lubelskie", "Lubuskie", "Łódzkie", "Małopolskie", "Mazowieckie", "Opolskie", "Podkarpackie", "Podlaskie", "Pomorskie", "Śląskie", "Świętokrzyskie", "Warmińsko-Mazurskie", "Wielkopolskie", "Zachodniopomorskie"])
 
#Second range - different schema
for i in range(2000,2006):
    x = "http://wwwold.pzh.gov.pl/oldpage/epimeld/grypa/"+str(i)+"/"+str(i)+".htm"

    soup = BeautifulSoup(x, 'html.parser')

    http = urllib3.PoolManager()
    response = http.request('GET', x)
    soup = BeautifulSoup(response.data)
    for a in soup.find_all('a', href=True):
        if a['href'].startswith("G"):
            x = "http://wwwold.pzh.gov.pl/oldpage/epimeld/grypa/"+str(i)+"/"+a['href']
            #Download
#Open downloaded and extract

# %%
import PyPDF2 
  
pdfFileObj = open('G_20_01B.pdf', 'rb') 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 
  
print(pdfReader.numPages) 
pageObj = pdfReader.getPage(0) 
  
# print(pageObj.extractText())
